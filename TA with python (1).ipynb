# %%
# !pip install yfinance
import pandas as pd
import numpy as np

# %%
import talib

# %%
import yfinance as yf

# %%
start="2020-01-01"
end="2021-01-01"
data_1=yf.download("SCC.BK")
data_1
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-04   74.000000   75.199997   74.000000   74.400002   31.359837
# 2000-01-05   73.199997   73.199997   70.000000   70.000000   29.505217
# 2000-01-06   70.400002   70.400002   62.799999   62.799999   26.470392
# 2000-01-07   64.000000   67.199997   64.000000   66.800003   28.156406
# 2000-01-10   68.000000   70.800003   68.000000   69.199997   29.168020
# ...                ...         ...         ...         ...         ...
# 2022-06-27  377.000000  382.000000  376.000000  381.000000  381.000000
# 2022-06-28  380.000000  382.000000  378.000000  382.000000  382.000000
# 2022-06-29  379.000000  380.000000  376.000000  380.000000  380.000000
# 2022-06-30  379.000000  379.000000  373.000000  374.000000  374.000000
# 2022-07-01  375.000000  380.000000  375.000000  378.000000  378.000000
#
#               Volume
# Date
# ...

# %%
RSI = talib.RSI(data_1['Close'], timeperiod=14)
RSI
# Out:
# Date
# 2000-01-04          NaN
# 2000-01-05          NaN
# 2000-01-06          NaN
# 2000-01-07          NaN
# 2000-01-10          NaN
#                 ...
# 2022-06-27    69.867390
# 2022-06-28    70.624657
# 2022-06-29    66.998141
# 2022-06-30    57.464877
# 2022-07-01    61.407418
# Length: 5592, dtype: float64

# %%
RSI.tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  31.884056969466112,
#  31.884056969466112,
#  29.875448253924013,
#  32.17613737139442,
#  34.490744354664784,
#  32.12913826217639,
#  34.54247608172678,
#  33.26852434102521,
#  34.56793638257979,
#  35.911859337211965,
#  35.911859337211965,
#  32.78774623292796,
#  31.320599305565928,
#  28.884730039777256,
#  27.254254125397388,
#  20.901318600041215,
#  18.9940877559503,
#  22.787848331996745,
#  19.122848358010536,
#  18.450088820092844,
#  18.450088820092848,
#  16.588757187114933,
#  18.9891401551697,
#  24.452256951489545,
#  24.45225695148954,
#  22.445957280738508,
#  20.6236249813879,
#  17.886816075173723,
#  21.874310642693374,
#  22.682994130364307,
#  36.1964415017101,
#  39.20765267911906,
#  39.20765267911906,
#  45.205963542633185,
#  44.73065929428929,
#  39.37991064457167,
#  42.46801835848721,
#  42.468018358487214,
#  42.46801835848721,
# ...

# %%
MA = talib.MA(data_1['Close'], timeperiod=30, matype=0)
MA.tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  64.66666679382324,
#  63.913333384195965,
#  63.340000025431316,
#  62.88000005086263,
#  62.259999974568686,
#  61.56000010172526,
#  60.813333384195964,
#  60.086666615804035,
#  59.4066665649414,
#  58.77999979654948,
#  58.04666646321615,
#  57.29999987284342,
#  56.513333257039385,
#  55.81333325703939,
#  55.09333318074544,
#  54.51333312988281,
#  53.96666641235352,
#  53.4733331044515,
#  53.0199998219808,
#  52.53333307902018,
#  52.0199998219808,
#  51.513333257039385,
#  51.03333333333333,
#  50.54000002543132,
#  50.15333340962728,
#  49.71333351135254,
#  49.30666681925456,
#  48.920000076293945,
#  48.566666793823245,
#  48.24666684468587,
#  48.166666920979814,
#  48.18000030517578,
#  48.18666699727376,
#  48.320000330607094,
# ...

# %%
macd, macdsignal, macdhist = talib.MACD(data_1['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
macd.tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  -4.544110167857816,
#  -4.7957905074338,
#  -5.1138217117527915,
#  -5.25685116208134,
#  -5.197323103583948,
#  -5.091455557996717,
#  -5.078123820124681,
#  -5.13744387964492,
#  -5.348735103255123,
#  -5.373550334251661,
#  -5.31580094913695,
#  -4.906842933921027,
#  -4.450743714775555,
#  -4.04268029561856,
#  -3.5173578983232616,
#  -3.0816511476474915,
#  -2.896619737068171,
#  -2.6388701163912884,
#  -2.4068569364718897,
#  -2.197651659481238,
#  -1.7215205623708485,
#  -1.45650011599065,
#  -1.2801281526527504,
#  -1.1433111122931194,
#  -1.054997737264678,
#  -0.9737835803362387,
#  -0.7235583699688064,
#  -0.4554496948445461,
#  -0.17638512767575776,
#  0.04426528965221621,
#  0.18472614686582034,
# ...

# %%
volume=data_1['Volume']

# %%
OBV = talib.OBV(data_1['Close'], data_1['Volume'])

# %%
data = {'RSI': RSI,
        'MA30': MA,
        'MACD': macd,
        'OBV':OBV,
        'Volume':volume}
df=pd.DataFrame(data)
df
# Out:
#                   RSI        MA30      MACD           OBV    Volume
# Date
# 2000-01-04        NaN         NaN       NaN  4.750000e+06   4750000
# 2000-01-05        NaN         NaN       NaN -6.400000e+05   5390000
# 2000-01-06        NaN         NaN       NaN -4.220000e+07  41560000
# 2000-01-07        NaN         NaN       NaN -3.007000e+07  12130000
# 2000-01-10        NaN         NaN       NaN -1.674000e+07  13330000
# ...               ...         ...       ...           ...       ...
# 2022-06-27  69.867390  364.266667  1.675887  1.533145e+09   4484600
# 2022-06-28  70.624657  365.066667  2.727296  1.536427e+09   3282100
# 2022-06-29  66.998141  365.700000  3.360426  1.533245e+09   3181500
# 2022-06-30  57.464877  366.066667  3.339540  1.530211e+09   3034300
# 2022-07-01  61.407418  366.700000  3.604207  1.532202e+09   1990900
#
# [5592 rows x 5 columns]

# %%
df.loc[df['RSI'].isna(), ['RSI','MA30','MACD']]
# Out:
#             RSI  MA30  MACD
# Date
# 2000-01-04  NaN   NaN   NaN
# 2000-01-05  NaN   NaN   NaN
# 2000-01-06  NaN   NaN   NaN
# 2000-01-07  NaN   NaN   NaN
# 2000-01-10  NaN   NaN   NaN
# 2000-01-11  NaN   NaN   NaN
# 2000-01-12  NaN   NaN   NaN
# 2000-01-13  NaN   NaN   NaN
# 2000-01-14  NaN   NaN   NaN
# 2000-01-17  NaN   NaN   NaN
# 2000-01-18  NaN   NaN   NaN
# 2000-01-19  NaN   NaN   NaN
# 2000-01-20  NaN   NaN   NaN
# 2000-01-21  NaN   NaN   NaN

# %%
df.loc[df['MA30'].isna(), ['RSI','MA30','MACD']]
# Out:
#                   RSI  MA30  MACD
# Date
# 2000-01-04        NaN   NaN   NaN
# 2000-01-05        NaN   NaN   NaN
# 2000-01-06        NaN   NaN   NaN
# 2000-01-07        NaN   NaN   NaN
# 2000-01-10        NaN   NaN   NaN
# 2000-01-11        NaN   NaN   NaN
# 2000-01-12        NaN   NaN   NaN
# 2000-01-13        NaN   NaN   NaN
# 2000-01-14        NaN   NaN   NaN
# 2000-01-17        NaN   NaN   NaN
# 2000-01-18        NaN   NaN   NaN
# 2000-01-19        NaN   NaN   NaN
# 2000-01-20        NaN   NaN   NaN
# 2000-01-21        NaN   NaN   NaN
# 2000-01-24  31.884057   NaN   NaN
# 2000-01-25  31.884057   NaN   NaN
# 2000-01-26  29.875448   NaN   NaN
# 2000-01-27  32.176137   NaN   NaN
# 2000-01-28  34.490744   NaN   NaN
# 2000-01-31  32.129138   NaN   NaN
# 2000-02-01  34.542476   NaN   NaN
# 2000-02-02  33.268524   NaN   NaN
# 2000-02-03  34.567936   NaN   NaN
# 2000-02-04  35.911859   NaN   NaN
# 2000-02-07  35.911859   NaN   NaN
# 2000-02-08  32.787746   NaN   NaN
# ...

# %%
df['RSI'].value_counts()
# Out:
# 38.896007    5
# 60.443221    4
# 53.010098    4
# 31.562020    4
# 62.575631    4
#             ..
# 28.479764    1
# 41.821886    1
# 35.824293    1
# 31.884869    1
# 61.407418    1
# Name: RSI, Length: 4931, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                   RSI        MA30      MACD           OBV    Volume
# Date
# 2000-02-18  18.450089   62.260000 -4.544110 -2.548900e+08  31230000
# 2000-02-21  18.450089   61.560000 -4.795791 -2.548900e+08         0
# 2000-02-22  16.588757   60.813333 -5.113822 -2.999700e+08  45080000
# 2000-02-23  18.989140   60.086667 -5.256851 -2.765200e+08  23450000
# 2000-02-24  24.452257   59.406667 -5.197323 -2.324700e+08  44050000
# ...               ...         ...       ...           ...       ...
# 2022-06-27  69.867390  364.266667  1.675887  1.533145e+09   4484600
# 2022-06-28  70.624657  365.066667  2.727296  1.536427e+09   3282100
# 2022-06-29  66.998141  365.700000  3.360426  1.533245e+09   3181500
# 2022-06-30  57.464877  366.066667  3.339540  1.530211e+09   3034300
# 2022-07-01  61.407418  366.700000  3.604207  1.532202e+09   1990900
#
# [5559 rows x 5 columns]

# %%
df['OBV']
# Out:
# Date
# 2000-02-18   -2.548900e+08
# 2000-02-21   -2.548900e+08
# 2000-02-22   -2.999700e+08
# 2000-02-23   -2.765200e+08
# 2000-02-24   -2.324700e+08
#                   ...
# 2022-06-27    1.533145e+09
# 2022-06-28    1.536427e+09
# 2022-06-29    1.533245e+09
# 2022-06-30    1.530211e+09
# 2022-07-01    1.532202e+09
# Name: OBV, Length: 5559, dtype: float64
